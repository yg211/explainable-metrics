# %%
from pair_explainer import ExplainableSTS
# initialise the explainable sts model
model = ExplainableSTS()

# %%
# entity change
s1 = 'Charlton coach Guy Luzon had said on Monday'
s2 = 'Charlton coach Bordeaux had said on Monday'

# get the similarity score between the sentences
sim_score = model(s1, s2) 
print('predicted similarity score:', sim_score)

# get the explanation
model.explain(s1, s2, plot=True)
# Out:
# predicted similarity score: 0.5335588
# [('s1_Charlton', 0.01673947771390279),
#  ('s1_coach', 0.06879958427614635),
#  ('s1_Guy', -0.007622201823525959),
#  ('s1_Luzon', -0.08069250235954921),
#  ('s1_had', 0.031216054326958127),
#  ('s1_said', 0.02350659668445587),
#  ('s1_on', 0.036917960478199854),
#  ('s1_Monday', 0.02147308157549964),
#  ('s2_Charlton', 0.10920861528979407),
#  ('s2_coach', 0.04147859952516026),
#  ('s2_Bordeaux', -0.14551988906330532),
#  ('s2_had', 0.020612753099865384),
#  ('s2_said', 0.04901947246657477),
#  ('s2_on', 0.005168127516905467),
#  ('s2_Monday', 0.06618944803873698)]

# %%
# negation
s1 = 'Snow was predicted later in the weekend for Atlanta and areas even further south.'
s2 = 'Snow wasn’t predicted later in the weekend for Atlanta and areas even further south.'

sim_score = model(s1, s2) 
print('predicted similarity score:', sim_score)
model.explain(s1, s2, plot=True)
# Out:
# predicted similarity score: 0.41594428
# [('s1_Snow', -0.01298250589105818),
#  ('s1_was', -0.003113145629564921),
#  ('s1_predicted', 0.028057459327909682),
#  ('s1_later', 0.0169708165857527),
#  ('s1_in', -0.0006420446766747369),
#  ('s1_the', 0.002032016714413961),
#  ('s1_weekend', 0.03319388131300608),
#  ('s1_for', 0.001707875066333347),
#  ('s1_Atlanta', -0.0176236629486084),
#  ('s1_and', 0.0010809650023778279),
#  ('s1_areas', 0.03106829110119078),
#  ('s1_even', 0.009933706786897447),
#  ('s1_further', 0.01704210705227322),
#  ('s1_south', 0.04132936729325189),
#  ('s1_.', -0.0003779414627287123),
#  ('s2_Snow', 0.0029978735579384696),
#  ('s2_wasn', -0.07238610254393683),
#  ('s2_’', 0.017994854185316298),
#  ('s2_t', -0.13033411072360146),
#  ('s2_predicted', 0.004590867294205559),
#  ('s2_later', -0.011360582378175523),
#  ('s2_in', 0.015038551555739509),
#  ('s2_the', 0.0029043604930241904),
#  ('s2_weekend', 0.05792423254913754),
#  ('s2_for', -0.0004819399780697293),
#  ('s2_Atlanta', -0.004103804628054301),
#  ('s2_and', 0.003299419250753191),
#  ('s2_areas', 0.00014420184824201796),
#  ('s2_even', 0.009780449171861013),
#  ('s2_further', 0.04175234337647756),
#  ('s2_south', 0.05878913485341602),
#  ('s2_.', 0.00247362752755483)]

# %%
# pronoun swap
s1 = 'Tom is his father'
s2 = 'Tom is her dad'

sim_score = model(s1, s2) 
print('predicted similarity score:', sim_score)
model.explain(s1, s2, plot=True)
# Out:
# predicted similarity score: 0.5546336
# [('s1_Tom', 0.048121808303727046),
#  ('s1_is', 0.014609408047464158),
#  ('s1_his', 0.02577577531337738),
#  ('s1_father', 0.05056784715917376),
#  ('s2_Tom', 0.06969272428088719),
#  ('s2_is', 0.06118933525350359),
#  ('s2_her', -0.11934025751219855),
#  ('s2_dad', 0.10348427792390187)]

# %%
# number change
s1 = 'He says he wants to pay off the $12.6 million lien'
s2 = 'He says he wants to pay off the $3.45 million lien'

sim_score = model(s1, s2) 
print('predicted similarity score:', sim_score)
model.explain(s1, s2, plot=True)
# Out:
# predicted similarity score: 0.50305086
# [('s1_He', 0.013903145988782247),
#  ('s1_says', 0.0060872336228688555),
#  ('s1_he', 0.0022614498933156333),
#  ('s1_wants', 0.046708979540401034),
#  ('s1_to', -0.0015055487553278606),
#  ('s1_pay', 0.06369251343939039),
#  ('s1_off', 0.03351037369834052),
#  ('s1_the', -0.013342044419712491),
#  ('s1_$', 0.005760941240522597),
#  ('s1_12.6', -0.08610260983308156),
#  ('s1_million', 0.06151620712545183),
#  ('s1_lien', 0.04323577880859375),
#  ('s2_He', 0.016146502561039396),
#  ('s2_says', 0.0068574994802474976),
#  ('s2_he', 0.0022108074691560534),
#  ('s2_wants', 0.007955994870927598),
#  ('s2_to', 0.0008357895745171441),
#  ('s2_pay', 0.05759265191025204),
#  ('s2_off', 0.03318001661035749),
#  ('s2_the', 0.008477626575364007),
#  ('s2_$', 0.012760210368368361),
#  ('s2_3.45', -0.14500685201750863),
#  ('s2_million', -0.0023703575134277344),
#  ('s2_lien', 0.0497526079416275)]

# %%
# preposition change
s1 = 'Her birthday was in July'
s2 = 'Her birthday was before July'

sim_score = model(s1, s2) 
print('predicted similarity score:', sim_score)
model.explain(s1, s2, plot=True)
# Out:
# predicted similarity score: 0.5766674
# [('s1_Her', 0.06417271163728502),
#  ('s1_birthday', 0.08763514459133148),
#  ('s1_was', 0.02744375831551022),
#  ('s1_in', -0.004678424861696031),
#  ('s1_July', 0.07153016991085476),
#  ('s2_Her', -0.0022728972964816624),
#  ('s2_birthday', 0.02295503516991933),
#  ('s2_was', 0.03231850266456604),
#  ('s2_before', -0.06174884570969476),
#  ('s2_July', 0.041785437199804515)]

# %%
# entity swap
s1 = 'Tom gave James a gift.'
s2 = 'James gave Tom a gift.'

sim_score = model(s1, s2) 
print('predicted similarity score:', sim_score)
model.explain(s1, s2, plot=True)
# Out:
# predicted similarity score: 0.30937257
# [('s1_Tom', -0.1073256383339564),
#  ('s1_gave', 0.03939925796455807),
#  ('s1_James', -0.04743986494011349),
#  ('s1_a', 0.00920125510957506),
#  ('s1_gift', 0.04482183357079824),
#  ('s1_.', -0.004814394646220737),
#  ('s2_James', 0.013005162278811136),
#  ('s2_gave', 0.0027972012758255005),
#  ('s2_Tom', -0.009463783767488267),
#  ('s2_a', 0.0011573566330803765),
#  ('s2_gift', 0.07775602572494084),
#  ('s2_.', -0.0030832323763105604)]
