# %%
from sts_pair_explainer import ExplainableSTS
# initialise the explainable sts metric
model = ExplainableSTS('bert-score') # to use sbert, pass argument 'sbert'

# %%
s1 = 'He hates apples'
s2 = 'He likes apples'

# get the similarity score between the sentences
sim_score = model(s1, s2) 
print('predicted similarity score:', sim_score)

# get the explanation
model.explain(s1, s2, plot=True)
# Out:
# predicted similarity score: 0.8767051696777344
# [('s1_He', 0.043545370078939785),
#  ('s1_hates', -0.1881576411032192),
#  ('s1_apples', 0.12763600269428188),
#  ('s2_He', 0.007480346115616148),
#  ('s2_likes', -0.031646479031562015),
#  ('s2_apples', -0.08215230986703276)]

# %%
# entity change
s1 = 'Charlton coach Guy Luzon disappeared on Monday'
s2 = 'Charlton coach Bordeaux disappeared on Monday'

# get the similarity score between the sentences
sim_score = model(s1, s2) 
print('predicted similarity score:', sim_score)

# get the explanation
model.explain(s1, s2, plot=True)
# Out:
# predicted similarity score: 0.8903520064264869
# [('s1_Charlton', -0.02225234020650873),
#  ('s1_coach', 0.07230446992174094),
#  ('s1_Guy', -0.06020423415356088),
#  ('s1_Luzon', -0.00666062365705147),
#  ('s1_disappeared', 0.024416648776339436),
#  ('s1_on', -0.010873046623275076),
#  ('s1_Monday', -0.05807917792330881),
#  ('s2_Charlton', 0.06289562406148258),
#  ('s2_coach', -0.11258752308241411),
#  ('s2_Bordeaux', 0.004415227692969487),
#  ('s2_disappeared', 0.017076767425009416),
#  ('s2_on', 0.03005540796995681),
#  ('s2_Monday', 0.03029179624883825)]

# %%
# negation
s1 = 'Snow was predicted later in the weekend for Atlanta and areas even further south.'
s2 = 'Snow wasn’t predicted later in the weekend for Atlanta and areas even further south.'

sim_score = model(s1, s2) 
print('predicted similarity score:', sim_score)
model.explain(s1, s2, plot=True)
# Out:
# predicted similarity score: 0.905834861387696
# Permutation explainer: 2it [00:21, 21.94s/it]
# [('s1_Snow', 0.006281330861074408),
#  ('s1_was', -0.013096149894519448),
#  ('s1_predicted', -0.024732494284380194),
#  ('s1_later', -0.009993045685831),
#  ('s1_in', -0.018391441571249858),
#  ('s1_the', -0.014384768260207218),
#  ('s1_weekend', -0.0250433831620557),
#  ('s1_for', 0.002856167984559763),
#  ('s1_Atlanta', 0.02152989701888229),
#  ('s1_and', 0.0012764103028294954),
#  ('s1_areas', -0.039100190626064485),
#  ('s1_even', -0.012598748604206574),
#  ('s1_further', -0.01914960037039273),
#  ('s1_south', 0.0010558361693048617),
#  ('s1_.', -0.012678518391870976),
#  ('s2_Snow', 0.05053143895477211),
#  ('s2_wasn', -0.043481354944800904),
#  ('s2_’', -0.009363528797786076),
#  ('s2_t', 0.007774939916204914),
#  ('s2_predicted', 0.00987243941603507),
#  ('s2_later', -0.0064829802301549595),
#  ('s2_in', -0.02324302114068809),
#  ('s2_the', 0.0041361094245823005),
#  ('s2_weekend', 0.026619872507326003),
#  ('s2_for', -0.012567876378044067),
#  ('s2_Atlanta', 0.006793686729810992),
#  ('s2_and', 0.009130139818083836),
#  ('s2_areas', 0.03339287479422018),
#  ('s2_even', 0.04063386454591706),
#  ('s2_further', 0.027234461170780964),
#  ('s2_south', 0.02468050163614059),
#  ('s2_.', -0.009767729760005568)]

# %%
# pronoun swap
s1 = 'Tom is his father'
s2 = 'Tom is her dad'

sim_score = model(s1, s2) 
print('predicted similarity score:', sim_score)
model.explain(s1, s2, plot=True)
# Out:
# predicted similarity score: 0.8777164816856384
# [('s1_Tom', -0.016707792056013644),
#  ('s1_is', 0.01858676809494184),
#  ('s1_his', -0.051126501799530176),
#  ('s1_father', 0.08242481207055846),
#  ('s2_Tom', 0.0660231135471645),
#  ('s2_is', -0.1149728935555428),
#  ('s2_her', -0.03915335652639866),
#  ('s2_dad', -0.06735766808954108)]

# %%
# number change
s1 = 'He says he wants to pay off the $12.6 million lien'
s2 = 'He says he wants to pay off the $3.45 million lien'

sim_score = model(s1, s2) 
print('predicted similarity score:', sim_score)
model.explain(s1, s2, plot=True)
# Out:
# predicted similarity score: 0.9545995412356555
# Permutation explainer: 2it [00:16, 16.11s/it]
# [('s1_He', -0.03272399596125091),
#  ('s1_says', 0.012462538299959827),
#  ('s1_he', -0.040407317830028676),
#  ('s1_wants', -0.06986915698605521),
#  ('s1_to', -0.009721255728347946),
#  ('s1_pay', 0.026522463936756637),
#  ('s1_off', 0.02246125260619272),
#  ('s1_the', 0.01691707887511372),
#  ('s1_$', -0.035643945174532635),
#  ('s1_12.6', -0.02511425654969943),
#  ('s1_million', 0.008496257977506527),
#  ('s1_lien', -0.034367838839567386),
#  ('s2_He', 0.02464703561982477),
#  ('s2_says', 0.013227589631615065),
#  ('s2_he', 0.007855335031941222),
#  ('s2_wants', 0.025372578150948386),
#  ('s2_to', -0.023477280105627305),
#  ('s2_pay', 0.029498917371651914),
#  ('s2_off', -0.000798111252559957),
#  ('s2_the', -0.03075232073908036),
#  ('s2_$', -0.00026540544269653625),
#  ('s2_3.45', 0.026056114713572647),
#  ('s2_million', 0.03130054072544966),
#  ('s2_lien', 0.0129226036952792)]

# %%
# preposition change
s1 = 'Her birthday was in July'
s2 = 'Her birthday was before July'

sim_score = model(s1, s2) 
print('predicted similarity score:', sim_score)
model.explain(s1, s2, plot=True)
# Out:
# predicted similarity score: 0.6358326788351243
# [('s1_Her', -0.08406599135021528),
#  ('s1_birthday', -0.01745624494801601),
#  ('s1_was', -0.01912208757458715),
#  ('s1_in', -0.12020942125825279),
#  ('s1_July', -0.08232271538350294),
#  ('s2_Her', 0.054424212340898635),
#  ('s2_birthday', 0.036486967723232816),
#  ('s2_was', -0.07383785998261924),
#  ('s2_before', -0.008197289825621838),
#  ('s2_July', -0.049866890906191876)]

# %%
# entity swap
s1 = 'Tom gave James a gift.'
s2 = 'James gave Tom a gift.'

sim_score = model(s1, s2) 
print('predicted similarity score:', sim_score)
model.explain(s1, s2, plot=True)
# Out:
# predicted similarity score: 0.980179488658905
# [('s1_Tom', -0.03377589494578884),
#  ('s1_gave', 0.029583743866738066),
#  ('s1_James', -0.016980542732906872),
#  ('s1_a', -0.02333215721300905),
#  ('s1_gift', 0.1053264002544937),
#  ('s1_.', -0.011356968858906222),
#  ('s2_James', 0.003102941303596063),
#  ('s2_gave', 0.006805156058272193),
#  ('s2_Tom', 0.008665598249434199),
#  ('s2_a', 0.0027567780211015863),
#  ('s2_gift', -0.09436981338036445),
#  ('s2_.', 0.003754248036244671)]
