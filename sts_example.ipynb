# %%
from pair_explainer import ExplainableSTS
# initialise the explainable sts model
model = ExplainableSTS('bert-score')
# Out:
# "sox" backend is being deprecated. The default backend will be changed to "sox_io" backend in 0.8.0 and "sox" backend will be removed in 0.9.0. Please migrate to "sox_io" backend. Please refer to https://github.com/pytorch/audio/issues/903 for the detail.

# %%
# entity change
s1 = 'Charlton coach Guy Luzon had said on Monday'
s2 = 'Charlton coach Bordeaux had said on Monday'

# get the similarity score between the sentences
sim_score = model(s1, s2) 
print('predicted similarity score:', sim_score)

# get the explanation
model.explain(s1, s2, plot=True)
# Out:
# predicted similarity score: 0.8969312155430165
# Permutation explainer: 2it [00:13, 13.12s/it]
# [('s1_Charlton', 0.0001476292906076562),
#  ('s1_coach', 0.006244110011207042),
#  ('s1_Guy', -0.03662241409896995),
#  ('s1_Luzon', -0.010817134598356568),
#  ('s1_had', -0.03956795229455252),
#  ('s1_said', -0.023078761266637944),
#  ('s1_on', -0.03720411626702285),
#  ('s1_Monday', 0.01299613870932586),
#  ('s2_Charlton', 0.009082681237739044),
#  ('s2_coach', 0.04287355746787705),
#  ('s2_Bordeaux', -0.05613051608526766),
#  ('s2_had', 0.06135185867751495),
#  ('s2_said', 0.04212080577775679),
#  ('s2_on', -0.00222878505041662),
#  ('s2_Monday', -0.042762328522027514)]

# %%
# negation
s1 = 'Snow was predicted later in the weekend for Atlanta and areas even further south.'
s2 = 'Snow wasn’t predicted later in the weekend for Atlanta and areas even further south.'

sim_score = model(s1, s2) 
print('predicted similarity score:', sim_score)
model.explain(s1, s2, plot=True)
# Out:
# predicted similarity score: 0.9058349216692224
# Permutation explainer: 2it [00:27, 27.08s/it]
# [('s1_Snow', 0.015569713682580902),
#  ('s1_was', -0.09010289857209124),
#  ('s1_predicted', 0.008364893162078188),
#  ('s1_later', -0.045609797128413364),
#  ('s1_in', -0.014372267898277835),
#  ('s1_the', -0.046789771627192445),
#  ('s1_weekend', -0.016886325222524663),
#  ('s1_for', 0.017172940875484155),
#  ('s1_Atlanta', -0.01042778992943986),
#  ('s1_and', 0.003012905662390566),
#  ('s1_areas', 0.032849321805110195),
#  ('s1_even', -0.004562448858435992),
#  ('s1_further', -0.0676192322354674),
#  ('s1_south', -0.016018144118303577),
#  ('s1_.', -0.003957490884466976),
#  ('s2_Snow', 0.023156944859061626),
#  ('s2_wasn', -0.03849965792182708),
#  ('s2_’', 0.0033592304914150167),
#  ('s2_t', 0.025738629853654913),
#  ('s2_predicted', 0.014285465058504206),
#  ('s2_later', 0.06383015257725368),
#  ('s2_in', 0.013344270491865817),
#  ('s2_the', 0.005041963725845089),
#  ('s2_weekend', 0.010524450844689004),
#  ('s2_for', 0.003636342196335968),
#  ('s2_Atlanta', -0.0013678800489681756),
#  ('s2_and', -0.013316760670975179),
#  ('s2_areas', 0.010765002464131404),
#  ('s2_even', 0.01403874791943232),
#  ('s2_further', 0.04487567188423934),
#  ('s2_south', 0.04356615366215556),
#  ('s2_.', -0.003877670679246079)]

# %%
# pronoun swap
s1 = 'Tom is his father'
s2 = 'Tom is her dad'

sim_score = model(s1, s2) 
print('predicted similarity score:', sim_score)
model.explain(s1, s2, plot=True)
# Out:
# predicted similarity score: 0.8777163624763489
# [('s1_Tom', -0.02242191291585373),
#  ('s1_is', 0.030367832920484433),
#  ('s1_his', -0.008997304433060484),
#  ('s1_father', -0.0755125317507328),
#  ('s2_Tom', 0.10307005383280934),
#  ('s2_is', -0.15035173955095552),
#  ('s2_her', -0.051997710528492995),
#  ('s2_dad', 0.05355967490215057)]

# %%
# number change
s1 = 'He says he wants to pay off the $12.6 million lien'
s2 = 'He says he wants to pay off the $3.45 million lien'

sim_score = model(s1, s2) 
print('predicted similarity score:', sim_score)
model.explain(s1, s2, plot=True)
# Out:
# predicted similarity score: 0.954599479798256
# Permutation explainer: 2it [00:19, 19.67s/it]
# [('s1_He', -0.025718234242220542),
#  ('s1_says', -0.01434151755550185),
#  ('s1_he', 0.02507859028211823),
#  ('s1_wants', -0.04982583874984471),
#  ('s1_to', -0.016540793601658426),
#  ('s1_pay', -0.01708894141857964),
#  ('s1_off', -0.0020796897331440845),
#  ('s1_the', 0.004386231135289082),
#  ('s1_$', 0.01051801587068023),
#  ('s1_12.6', 0.016319448294905156),
#  ('s1_million', -0.0026648812382062096),
#  ('s1_lien', 0.039186417552336046),
#  ('s2_He', 0.006228147117500218),
#  ('s2_says', 0.042653358420208294),
#  ('s2_he', 0.0077746423631159306),
#  ('s2_wants', 0.03400990516476879),
#  ('s2_to', 0.007956199602751611),
#  ('s2_pay', -0.007021867489236043),
#  ('s2_off', -0.06411508678821269),
#  ('s2_the', -0.011545711813762786),
#  ('s2_$', 0.01913752376961268),
#  ('s2_3.45', -0.028058596449461168),
#  ('s2_million', 0.026416949417539495),
#  ('s2_lien', -0.04606479011274166)]

# %%
# preposition change
s1 = 'Her birthday was in July'
s2 = 'Her birthday was before July'

sim_score = model(s1, s2) 
print('predicted similarity score:', sim_score)
model.explain(s1, s2, plot=True)
# Out:
# predicted similarity score: 0.6358299350625904
# [('s1_Her', 0.01924029876466662),
#  ('s1_birthday', 0.048966842764534405),
#  ('s1_was', 0.02213093519394392),
#  ('s1_in', -0.02767435411712497),
#  ('s1_July', -0.019708166293889225),
#  ('s2_Her', -0.14402200992467482),
#  ('s2_birthday', -0.11546784942783425),
#  ('s2_was', -0.07976024030552381),
#  ('s2_before', -0.08630976024031117),
#  ('s2_July', 0.018434119439514198)]

# %%
# entity swap
s1 = 'Tom gave James a gift.'
s2 = 'James gave Tom a gift.'

sim_score = model(s1, s2) 
print('predicted similarity score:', sim_score)
model.explain(s1, s2, plot=True)
# Out:
# predicted similarity score: 0.980179488658905
# Permutation explainer: 2it [00:10, 10.37s/it]
# [('s1_Tom', 0.02350761586650129),
#  ('s1_gave', -0.0680801222663353),
#  ('s1_James', -0.030603943038357846),
#  ('s1_a', -0.053453967985119824),
#  ('s1_gift', 0.021750239951708623),
#  ('s1_.', 0.0015522848302470774),
#  ('s2_James', 0.049556862482488945),
#  ('s2_gave', 0.05455457974634874),
#  ('s2_Tom', -0.033329001064742715),
#  ('s2_a', -0.03570572483110693),
#  ('s2_gift', 0.06550836921235913),
#  ('s2_.', -0.015077704245086192)]
